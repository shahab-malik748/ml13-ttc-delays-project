# %% [markdown]
# ## Create SQLite Database
#
# The goal of this notebook is to create a SQL database with all of the datasets from https://open.toronto.ca/dataset/ttc-subway-delay-data/.
#
# - #Step 1#: we manually updated ttc-subway-delay-codes by assigning each code and description a unique code number. We also grouped the all the codes into [##] delay categories. We converted the updated file to a csv.
#
# - #Step 2#: we created a major_events table to support our existing dataset. This table includes major sporting events, concerts, festivals and season events that took place in Toronto between 2014-2025. We used Copilot to compile this information.
#
# - #Step 3#: we converted our delay datatables from excel into csv. Some excel files had tabs split by month. We used the VBA code below to spit each tab into seperate csv file:
#
#   Sub ExportSheetsToCSV()
#                     Dim xWs As Worksheet
#                     Dim xcsvFile As String
#                     For Each xWs In Application.ActiveWorkbook.Worksheets
#                         xWs.Copy
#                         xcsvFile = Application.ThisWorkbook.Path & "\" & xWs.Name & ".csv"
#                         'adds the exported files to whichever folder the current workbook is saved under
#                         Application.ActiveWorkbook.SaveAs Filename:=xcsvFile, _
#                         FileFormat:=xlCSV, CreateBackup:=False
#                         Application.ActiveWorkbook.Saved = True
#                        Application.ActiveWorkbook.Close
#                    Next
#                End Sub
#
# - #Step 4#: Zip all the files together in the following location "C:\Users\aakav\dsi\ml13-ttc-delays-project\src_files\csv converted raw data.zip"
#
# - #Step 5#: run the following scripts below

# %%
import zipfile
import os
import sqlite3
import pandas as pd

# %%
# Define Paths
zip_path = r"C:\Users\aakav\dsi\ml13-ttc-delays-project\src_files\csv converted raw data.zip"
extract_folder = r"C:\Users\aakav\dsi\ml13-ttc-delays-project\src_files\unzipped_csvs_raw_data"
db_path = r"C:\Users\aakav\dsi\ml13-ttc-delays-project\src_files\ttc_delays.db"

# %%
#Unzip csvs
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_folder)
print(f"Unzipped to: {extract_folder}")
# Out:
# Unzipped to: C:\Users\aakav\dsi\ml13-ttc-delays-project\src_files\unzipped_csvs_raw_data

# %%
#Inspect column names and data types
print("\n📊 Column inspection:")
for filename in sorted(os.listdir(extract_folder)):
    file_path = os.path.join(extract_folder, filename)
    df = pd.read_csv(file_path, nrows=10)
    print(f"\n🧾 {filename}")
    print(df.dtypes)

## Brought this step in because I noticed TTC_Subway_Delay_Data_since_2025 had a unique "row count" id column which prevented us from unioning all the delay tables in SQL.
## Manually deleted this column in TTC_Subway_Delay_Data_since_2025 and re-ran this process
# Out:
# 📊 Column inspection:
#
# 🧾 Apr_19.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 April_20.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 April_2018.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 April_21.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 August_18.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 August_19.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 August_20.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 August_21.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 Dec_2018.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 Dec_2020.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 December_19.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 December_21.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 Feb_18.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 Feb_19.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 Feb_20.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 Feb_21.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 Jan_18.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 Jan_19.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 Jan_2020.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 January_21.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 July_18.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 July_19.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 July_20.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 July_21.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 June_19.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 June_20.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 June_2018.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 June_21.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 Mar_19.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 March_20.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 March_2018.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 March_21.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 May_19.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 May_20.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 May_2018.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 May_21.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 Nov_19.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 Nov_20.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 Nov_2018.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 Nov_21.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 Oct_18.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 Oct_19.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 Oct_20.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 Oct_21.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 Sept_18.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 Sept_20.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 Sept_21.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 September_19.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 TTC_Subway_Delay_Data_since_2025.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 major_events.csv
# Date                 object
# Time                 object
# Day                  object
# Event Description    object
# dtype: object
#
# 🧾 ttc_delay_codes_classified_with_cnc_flag.csv
# SUB RMENU CODE ID                int64
# SUB RMENU CODE                  object
# CODE DESCRIPTION                object
# Code classification by cause    object
# Controllable Flag                int64
# dtype: object
#
# 🧾 ttc_subway_delay_data_2022.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 ttc_subway_delay_data_2023.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 ttc_subway_delay_data_2024.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 ttc_subway_delay_jan_2014_april_2017.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object
#
# 🧾 ttc_subway_delay_may_december_2017.csv
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object

# %%
# Create SQLite DB
conn = sqlite3.connect(db_path)

# %%
# Import all contents in the SQLite DB
for filename in os.listdir(extract_folder):
    if filename.endswith(".csv"):
        table_name = os.path.splitext(filename)[0]
        file_path = os.path.join(extract_folder, filename)

        try:
            df = pd.read_csv(file_path)

            # Normalize dates to be the Y-M-D across all files that have it
            if 'Date' in df.columns:
                df['Date'] = pd.to_datetime(df['Date'], errors='coerce').dt.strftime('%Y-%m-%d')
                df = df.dropna(subset=['Date'])
            
            # Normalize Time to HH:MM format
            if 'Time' in df.columns:
                def pad_time(t):
                    try:
                        h, m = map(int, str(t).split(':'))
                        return f"{h:02d}:{m:02d}"
                    except:
                        return None  # or np.nan if using numpy

                df['Time'] = df['Time'].apply(pad_time)
                df = df.dropna(subset=['Time'])  # optional: drop malformed times

            # Write to SQLite DB
            df.to_sql(table_name, conn, if_exists='replace', index=False)
            print(f"Imported '{filename}' as table '{table_name}'")

        except Exception as e:
            print(f"Error importing '{filename}': {e}")

conn.close()
print(f"\n✅ All tables loaded into: {db_path}")
# Out:
# Imported 'April_20.csv' as table 'April_20'
# Imported 'April_2018.csv' as table 'April_2018'
# Imported 'April_21.csv' as table 'April_21'
# Imported 'Apr_19.csv' as table 'Apr_19'
# Imported 'August_18.csv' as table 'August_18'
# Imported 'August_19.csv' as table 'August_19'
# Imported 'August_20.csv' as table 'August_20'
# Imported 'August_21.csv' as table 'August_21'
# Imported 'December_19.csv' as table 'December_19'
# Imported 'December_21.csv' as table 'December_21'
# Imported 'Dec_2018.csv' as table 'Dec_2018'
# Imported 'Dec_2020.csv' as table 'Dec_2020'
# Imported 'Feb_18.csv' as table 'Feb_18'
# Imported 'Feb_19.csv' as table 'Feb_19'
# Imported 'Feb_20.csv' as table 'Feb_20'
# Imported 'Feb_21.csv' as table 'Feb_21'
# Imported 'January_21.csv' as table 'January_21'
# Imported 'Jan_18.csv' as table 'Jan_18'
# Imported 'Jan_19.csv' as table 'Jan_19'
# Imported 'Jan_2020.csv' as table 'Jan_2020'
# Imported 'July_18.csv' as table 'July_18'
# Imported 'July_19.csv' as table 'July_19'
# Imported 'July_20.csv' as table 'July_20'
# Imported 'July_21.csv' as table 'July_21'
# Imported 'June_19.csv' as table 'June_19'
# Imported 'June_20.csv' as table 'June_20'
# Imported 'June_2018.csv' as table 'June_2018'
# Imported 'June_21.csv' as table 'June_21'
# Imported 'major_events.csv' as table 'major_events'
# Imported 'March_20.csv' as table 'March_20'
# Imported 'March_2018.csv' as table 'March_2018'
# Imported 'March_21.csv' as table 'March_21'
# Imported 'Mar_19.csv' as table 'Mar_19'
# Imported 'May_19.csv' as table 'May_19'
# Imported 'May_20.csv' as table 'May_20'
# Imported 'May_2018.csv' as table 'May_2018'
# Imported 'May_21.csv' as table 'May_21'
# Imported 'Nov_19.csv' as table 'Nov_19'
# Imported 'Nov_20.csv' as table 'Nov_20'
# Imported 'Nov_2018.csv' as table 'Nov_2018'
# Imported 'Nov_21.csv' as table 'Nov_21'
# Imported 'Oct_18.csv' as table 'Oct_18'
# Imported 'Oct_19.csv' as table 'Oct_19'
# Imported 'Oct_20.csv' as table 'Oct_20'
# Imported 'Oct_21.csv' as table 'Oct_21'
# Imported 'September_19.csv' as table 'September_19'
# Imported 'Sept_18.csv' as table 'Sept_18'
# Imported 'Sept_20.csv' as table 'Sept_20'
# Imported 'Sept_21.csv' as table 'Sept_21'
# Imported 'ttc_delay_codes_classified_with_cnc_flag.csv' as table 'ttc_delay_codes_classified_with_cnc_flag'
# Imported 'ttc_subway_delay_data_2022.csv' as table 'ttc_subway_delay_data_2022'
# Imported 'ttc_subway_delay_data_2023.csv' as table 'ttc_subway_delay_data_2023'
# Imported 'ttc_subway_delay_data_2024.csv' as table 'ttc_subway_delay_data_2024'
# Imported 'TTC_Subway_Delay_Data_since_2025.csv' as table 'TTC_Subway_Delay_Data_since_2025'
# Imported 'ttc_subway_delay_jan_2014_april_2017.csv' as table 'ttc_subway_delay_jan_2014_april_2017'
# Imported 'ttc_subway_delay_may_december_2017.csv' as table 'ttc_subway_delay_may_december_2017'
#
# ✅ All tables loaded into: C:\Users\aakav\dsi\ml13-ttc-delays-project\src_files\ttc_delays.db

# %%
# Delete the unzipped raw folder
import shutil

shutil.rmtree(extract_folder)
